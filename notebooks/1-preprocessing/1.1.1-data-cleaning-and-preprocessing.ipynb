# %% [markdown]
# # Explore the data
#
# Explore the Ebola dataset and preprocess according to the study [rstb20160308](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5394646/pdf/rstb20160308.pdf).

# %%
import numpy as np
import pandas as pd
import networkx as nx
import json
import os

from matplotlib import pyplot as plt
# %matplotlib inline

from lib.settings import DATA_DIR

# %%
INPUT_FILE = os.path.join(DATA_DIR, 'ebola' , 'rstb20160308_si_001.csv')

# %% [markdown]
# Pick first rows of the dataset file.

# %%
# !head -n 3 $INPUT_FILE
# Out:
# "Country","EpiCaseDef","FinalStatus","DateOnset","DateOnsetInferred","DateReport","DateOutcomeComp","DateHospitalCurrentAdmit","Age","CL_DistrictRes","HospitalizedEver","TreatmentCendreType","TreatmentCentre","delay.onset.hospitalisation","QuarterOnsetInferred","retrospective"
# "Guinea","confirmed","Dead",2015-02-06,2015-02-06,2015-02-06,2015-02-06,NA,45,"FORECARIAH","No","Not Hospitalised",NA,NA,"Jan - Mar 2015",TRUE
# "Guinea","confirmed","Dead",2015-03-02,2015-03-02,2015-03-07,2015-03-07,NA,40,"CONAKRY","No","Not Hospitalised",NA,NA,"Jan - Mar 2015",TRUE

# %% [markdown]
# Load data.

# %%
date_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

df = pd.read_csv(INPUT_FILE)
for col in ['DateOnset', 'DateOnsetInferred', 'DateOutcomeComp']:
    df[col] = pd.to_datetime(df[col], format="%Y-%m-%d")
                              
df.index += 2  # Set index as in Excel file row number

df.retrospective = df.retrospective.astype(bool)

print(df.shape)
df.head(15)
# Out:
# (33338, 16)
#    Country EpiCaseDef FinalStatus  DateOnset DateOnsetInferred  DateReport DateOutcomeComp DateHospitalCurrentAdmit   Age CL_DistrictRes HospitalizedEver      TreatmentCendreType TreatmentCentre  delay.onset.hospitalisation QuarterOnsetInferred  retrospective
# 2   Guinea  confirmed        Dead 2015-02-06        2015-02-06  2015-02-06      2015-02-06                      NaN  45.0     FORECARIAH               No         Not Hospitalised             NaN                          NaN       Jan - Mar 2015           True
# 3   Guinea  confirmed        Dead 2015-03-02        2015-03-02  2015-03-07      2015-03-07                      NaN  40.0        CONAKRY               No         Not Hospitalised             NaN                          NaN       Jan - Mar 2015           True
# 4   Guinea  confirmed        Dead 2015-03-15        2015-03-15  2015-03-17      2015-03-18               2015-03-18   0.0     FORECARIAH              Yes                      ETU       Conakry 2                          3.0       Jan - Mar 2015          False
# 5   Guinea  confirmed        Dead 2014-06-06        2014-06-06  2014-06-09      2014-06-16               2014-06-09  30.0      GUECKEDOU              Yes                      ETU     Gueckedou 1                          3.0       Apr - Jun 2014          False
# 6   Guinea   probable        Dead 2014-02-27        2014-02-27  2014-02-27      2014-03-03                      NaN  46.0      GUECKEDOU              Yes          Unknown TC Type             NaN                          NaN       Jan - Mar 2014          False
# 7   Guinea  confirmed       Alive 2015-06-26        2015-06-26  2015-06-29      2015-07-15               2015-06-30  45.0           BOKE              Yes                 Hospital        Kindia 1                          4.0       Apr - Jun 2015          False
# 8   Guinea  confirmed        Dead 2014-11-17        2014-11-17  2014-11-23      2014-11-24                      NaN  13.0     N'ZEREKORE              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False
# 9   Guinea  confirmed       Alive 2014-08-29        2014-08-29  2014-08-30      2014-09-13               2014-08-29   0.0      GUECKEDOU              Yes                      ETU     Gueckedou 1                          0.0       Jul - Sep 2014          False
# 10  Guinea  confirmed        Dead 2014-08-16        2014-08-16  2014-08-18      2014-08-20               2014-08-18  72.0        MACENTA              Yes                      ETU     Gueckedou 1                          2.0       Jul - Sep 2014          False
# 11  Guinea  confirmed        Dead 2014-05-19        2014-05-19  2014-05-22      2014-05-25               2014-05-22   6.0      GUECKEDOU              Yes                      ETU     Gueckedou 1                          3.0       Apr - Jun 2014          False
# 12  Guinea  confirmed       Alive 2014-10-13        2014-10-13  2014-10-14      2014-11-03               2014-10-13  14.0       KEROUANE              Yes                      ETU       Conakry 2                          0.0       Oct - Dec 2014          False
# 13  Guinea   probable        Dead 2014-08-05        2014-08-05  2014-08-25             NaT                      NaN  25.0     FORECARIAH              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False
# 14  Guinea  confirmed       Alive 2014-11-13        2014-11-13  2014-11-16             NaT               2014-11-16  40.0        FARANAH              Yes                      ETU     Gueckedou 1                          3.0       Oct - Dec 2014          False
# 15  Guinea  confirmed        Dead 2014-10-11        2014-10-11  2014-10-14      2014-10-15                      NaN   NaN        MACENTA              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False
# 16  Guinea  confirmed       Alive 2014-11-12        2014-11-12  2014-11-14      2014-11-30               2014-11-13  50.0     N'ZEREKORE              Yes                      ETU       Macenta 2                          1.0       Oct - Dec 2014          False

# %%
df.dtypes
# Out:
# Country                                object
# EpiCaseDef                             object
# FinalStatus                            object
# DateOnset                      datetime64[ns]
# DateOnsetInferred              datetime64[ns]
# DateReport                             object
# DateOutcomeComp                datetime64[ns]
# DateHospitalCurrentAdmit               object
# Age                                   float64
# CL_DistrictRes                         object
# HospitalizedEver                       object
# TreatmentCendreType                    object
# TreatmentCentre                        object
# delay.onset.hospitalisation           float64
# QuarterOnsetInferred                   object
# retrospective                            bool
# dtype: object

# %% [markdown]
# ## Basic Data Exploration

# %% [markdown]
# Count the number of cases per district in the raw dataset

# %%
df[['CL_DistrictRes', 'Country']].groupby('CL_DistrictRes').count().sort_values('Country')
# Out:
#                   Country
# CL_DistrictRes
# DINGUIRAYE              1
# TOUGUE                  2
# MALI                    5
# BONTHE                  6
# GRAND GEDEH             8
# PITA                    8
# DALABA                  9
# YOMOU                  11
# DABOLA                 13
# MARYLAND               14
# RIVER GEE              17
# FRIA                   17
# KOUROUSSA              20
# GRAND KRU              26
# GBARPOLU               30
# KANKAN                 31
# SIGUIRI                33
# RIVERCESS              36
# SINOE                  37
# BOKE                   38
# TELIMELE               43
# BEYLA                  45
# BOFFA                  53
# FARANAH                67
# LOLA                  110
# KINDIA                110
# KISSIDOUGO            136
# GRAND BASSA           145
# DUBREKA               158
# KEROUANE              160
# GRAND CAPE MOUNT      175
# COYAH                 241
# BOMI                  244
# N'ZEREKORE            253
# NIMBA                 263
# MOYAMBA               292
# KOINADUGU             306
# GUECKEDOU             380
# BONG                  383
# FORECARIAH            470
# KAMBIA                599
# CONAKRY               609
# LOFA                  641
# MACENTA               731
# BO                    768
# KAILAHUN              920
# TONKOLILI            1037
# BOMBALI              1078
# MARGIBI              1080
# KENEMA               1144
# PUJEHUN              1218
# KONO                 1993
# PORT LOKO            3006
# MONTSERRADO          4331
# WESTERN              8803

# %% [markdown]
# Make sure that the `DateOnsetInferred` only differs when `DateOnset` is missing.

# %%
assert df[(df.DateOnset != df.DateOnsetInferred) & ~df.DateOnset.isna()].shape[0] == 0

# %% [markdown]
# A few cases have an inferred onset date prior to outcome date. This will be excluded from the analysis.

# %%
df[~((df.DateOnsetInferred <= df.DateOutcomeComp) | df.DateOutcomeComp.isna() | df.DateOnsetInferred.isna())]
# Out:
#             Country EpiCaseDef FinalStatus DateOnset DateOnsetInferred  DateReport DateOutcomeComp DateHospitalCurrentAdmit   Age CL_DistrictRes HospitalizedEver      TreatmentCendreType TreatmentCentre  delay.onset.hospitalisation QuarterOnsetInferred  retrospective
# 5884   Sierra Leone  suspected       Alive       NaT        2014-11-19  2014-10-31      2014-10-21                      NaN  25.0        WESTERN              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014           True
# 6485   Sierra Leone   probable       Alive       NaT        2014-12-24  2014-12-05      2014-12-06                      NaN  49.0             BO              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014          False
# 8583   Sierra Leone  confirmed        Dead       NaT        2014-11-14         NaN      2014-09-13                      NaN  50.0        WESTERN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False
# 9147   Sierra Leone  suspected         NaN       NaT        2014-10-29         NaN      2014-10-20                      NaN   NaN        WESTERN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False
# 9465   Sierra Leone  confirmed        Dead       NaT        2014-08-12  2014-07-02      2014-06-11                      NaN  35.0       KAILAHUN              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014           True
# 9512   Sierra Leone  suspected       Alive       NaT        2015-03-30  2015-04-04      2015-03-04                      NaN  35.0           KONO               No         Not Hospitalised             NaN                          NaN       Jan - Mar 2015           True
# 11129  Sierra Leone  suspected       Alive       NaT        2014-11-22  2014-11-22      2014-10-09                      NaN  42.0        WESTERN              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014           True
# 12364  Sierra Leone  suspected        Dead       NaT        2014-11-10  2014-11-12      2014-09-13                      NaN  17.0        WESTERN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014           True
# 15205  Sierra Leone  suspected        Dead       NaT        2015-03-08  2015-03-13      2015-03-03                      NaN   7.0           KONO               No         Not Hospitalised             NaN                          NaN       Jan - Mar 2015           True
# 20351  Sierra Leone  confirmed        Dead       NaT        2014-11-14         NaN      2014-09-15                      NaN  22.0        WESTERN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False
# 22006  Sierra Leone  confirmed       Alive       NaT        2014-10-03  2014-09-29      2014-09-29                      NaN  31.0        WESTERN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014           True
# 25570       Liberia  suspected       Alive       NaT        2014-10-02         NaN      2014-09-28                      NaN  52.0    MONTSERRADO              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014          False
# 27883       Liberia  confirmed       Alive       NaT        2014-08-22         NaN      2014-08-20                      NaN  23.0            NaN              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False
# 29091       Liberia   probable        Dead       NaT        2014-09-02  2014-09-05      2014-08-15                      NaN   3.0        MARGIBI               No         Not Hospitalised             NaN                          NaN       Jul - Sep 2014           True
# 29828       Liberia  confirmed         NaN       NaT        2014-10-04         NaN      2014-10-02                      NaN  28.0            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False

# %% [markdown]
# Count the number of null recovery dates.

# %%
df.DateOutcomeComp.isna().sum()
# Out:
# 21055

# %% [markdown]
# Visualize the long durations of infection.

# %%
df['Duration'] = df['DateOutcomeComp'] - df['DateOnsetInferred']
df.sort_values('Duration', ascending=False)
# Out:
#             Country EpiCaseDef FinalStatus  DateOnset DateOnsetInferred  DateReport DateOutcomeComp DateHospitalCurrentAdmit   Age CL_DistrictRes HospitalizedEver      TreatmentCendreType TreatmentCentre  delay.onset.hospitalisation QuarterOnsetInferred  retrospective Duration
# 19258  Sierra Leone  suspected        Dead 2014-05-17        2014-05-17         NaN      2015-05-15               2014-05-17  55.0      KOINADUGU              Yes                      ETU      Bombali 27                          0.0       Apr - Jun 2014          False 363 days
# 22002  Sierra Leone  suspected        Dead 2014-03-03        2014-03-03  2015-02-24      2015-02-24                      NaN   0.0        WESTERN              Yes          Unknown TC Type             NaN                          NaN       Jan - Mar 2014           True 358 days
# 9761   Sierra Leone  suspected       Alive 2014-10-29        2014-10-29  2014-11-19      2015-08-03                      NaN  33.0        WESTERN              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014          False 278 days
# 9778   Sierra Leone  suspected        Dead 2014-10-29        2014-10-29  2014-10-29      2015-07-30                      NaN  80.0           KONO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False 274 days
# 2227         Guinea  confirmed        Dead 2014-03-24        2014-03-24  2014-03-30      2014-12-10               2014-03-25  44.0        CONAKRY              Yes                      ETU       Conakry 2                          1.0       Jan - Mar 2014          False 261 days
# 26129       Liberia   probable       Alive 2014-03-03        2014-03-03  2014-09-06      2014-11-10                      NaN  12.0           BOMI              Yes                      ETU          Bomi 5                          NaN       Jan - Mar 2014          False 252 days
# 18452  Sierra Leone  suspected        Dead 2014-07-01        2014-07-01  2015-03-10      2015-03-10               2014-07-01  75.0        WESTERN              Yes                      ETU     Freetown 43                          0.0       Jul - Sep 2014           True 252 days
# 22675  Sierra Leone  suspected        Dead 2014-04-22        2014-04-22  2014-12-01      2014-11-30               2014-04-22  45.0           KONO              Yes                 Hospital         Kono 43                          0.0       Apr - Jun 2014           True 222 days
# 14187  Sierra Leone  confirmed       Alive 2014-10-01        2014-10-01  2014-11-05      2015-05-06               2014-10-03  28.0      PORT LOKO              Yes                      ETU    Port Loko 74                          2.0       Oct - Dec 2014          False 217 days
# 17496  Sierra Leone  suspected       Alive        NaT        2014-09-19  2014-09-23      2015-04-23               2014-09-22   1.0           KONO              Yes          Unknown TC Type         Kono 33                          NaN       Jul - Sep 2014          False 216 days
# 9113   Sierra Leone  confirmed       Alive 2014-10-05        2014-10-05  2014-10-11      2015-05-06               2014-10-11  14.0      PORT LOKO              Yes                 Hospital    Port Loko 70                          6.0       Oct - Dec 2014          False 213 days
# 3662         Guinea  confirmed        Dead 2014-05-19        2014-05-19  2014-05-21      2014-12-17               2014-05-21   2.0      GUECKEDOU              Yes                      ETU     Gueckedou 1                          2.0       Apr - Jun 2014          False 212 days
# 5029   Sierra Leone  confirmed       Alive 2014-09-04        2014-09-04  2014-09-08      2015-04-02                      NaN  56.0      PORT LOKO              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False 210 days
# 32360  Sierra Leone  suspected        Dead 2014-10-05        2014-10-05         NaN      2015-05-01               2014-10-05  10.0        WESTERN              Yes                 Hospital     Freetown 41                          0.0       Oct - Dec 2014          False 208 days
# 13435  Sierra Leone  confirmed       Alive 2014-09-16        2014-09-16  2014-09-20      2015-04-07               2014-09-19  39.0      PORT LOKO              Yes                      ETU    Port Loko 74                          3.0       Jul - Sep 2014          False 203 days
# 1710         Guinea   probable        Dead 2014-05-02        2014-05-02  2014-06-05      2014-11-20                      NaN  45.0          BOFFA              NaN  Hospitalisation Unknown             NaN                          NaN       Apr - Jun 2014          False 202 days
# 21803  Sierra Leone  confirmed       Alive 2014-09-18        2014-09-18  2014-09-22      2015-04-07                      NaN  38.0      PORT LOKO              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False 201 days
# 4501   Sierra Leone  confirmed       Alive 2014-10-04        2014-10-04  2014-10-15      2015-04-22               2014-10-13  35.0      PORT LOKO              Yes                      ETU    Port Loko 74                          9.0       Oct - Dec 2014          False 200 days
# 22370  Sierra Leone  confirmed       Alive 2014-09-15        2014-09-15  2014-09-20      2015-04-01               2014-09-19  45.0      PORT LOKO              Yes            Health Centre    Port Loko 65                          4.0       Jul - Sep 2014          False 198 days
# 12481  Sierra Leone  confirmed       Alive 2014-09-22        2014-09-22  2014-09-29      2015-04-07                      NaN  29.0      PORT LOKO              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False 197 days
# 14781  Sierra Leone  confirmed       Alive 2014-10-25        2014-10-25  2014-11-05      2015-05-06               2014-11-04  45.0      PORT LOKO              Yes                      ETU    Port Loko 74                         10.0       Oct - Dec 2014          False 193 days
# 12921  Sierra Leone  confirmed        Dead 2014-10-25        2014-10-25  2014-11-01      2015-05-04                      NaN   2.0      PORT LOKO               No         Not Hospitalised             NaN                          NaN       Oct - Dec 2014          False 191 days
# 18349  Sierra Leone  confirmed        Dead 2014-10-27        2014-10-27  2014-11-01      2015-05-04                      NaN  30.0      PORT LOKO              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014          False 189 days
# 11814  Sierra Leone  confirmed        Dead 2014-10-28        2014-10-28  2014-11-02      2015-05-04                      NaN  35.0      PORT LOKO               No         Not Hospitalised             NaN                          NaN       Oct - Dec 2014          False 188 days
# 32757  Sierra Leone  confirmed       Alive 2014-10-30        2014-10-30  2014-11-03      2015-05-06                      NaN  42.0      PORT LOKO              Yes                      ETU    Port Loko 74                          NaN       Oct - Dec 2014          False 188 days
# 4757   Sierra Leone  confirmed       Alive 2014-10-16        2014-10-16  2014-10-19      2015-04-22               2014-10-19  37.0      PORT LOKO              Yes           Holding Centre    Port Loko 59                          3.0       Oct - Dec 2014          False 188 days
# 23795  Sierra Leone  confirmed       Alive 2014-10-02        2014-10-02  2014-10-06      2015-04-07               2014-10-05  16.0      PORT LOKO              Yes                 Hospital    Port Loko 72                          3.0       Oct - Dec 2014          False 187 days
# 31986  Sierra Leone  suspected       Alive 2014-09-28        2014-09-28  2014-09-30      2015-04-03               2014-09-30  13.0      PORT LOKO              Yes                 Hospital    Port Loko 72                          2.0       Jul - Sep 2014          False 187 days
# 19265  Sierra Leone  confirmed       Alive 2014-09-26        2014-09-26  2014-09-28      2015-04-01                      NaN  24.0      PORT LOKO              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False 187 days
# 20360  Sierra Leone  confirmed       Alive 2014-10-30        2014-10-30  2014-11-02      2015-05-04                      NaN  50.0      PORT LOKO              Yes          Unknown TC Type             NaN                          NaN       Oct - Dec 2014          False 186 days
# ...             ...        ...         ...        ...               ...         ...             ...                      ...   ...            ...              ...                      ...             ...                          ...                  ...            ...      ...
# 33309       Liberia  confirmed         NaN        NaT        2014-08-21  2014-06-23             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33310       Liberia  confirmed        Dead        NaT        2014-08-13         NaN             NaT                      NaN  42.0            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33311       Liberia  confirmed        Dead 2014-08-27        2014-08-27         NaN             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33312       Liberia  confirmed         NaN 2014-09-01        2014-09-01         NaN             NaT                      NaN  14.0    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33313       Liberia  suspected         NaN        NaT        2014-10-07         NaN             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33314       Liberia  confirmed         NaN        NaT        2015-01-03  2014-11-12             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33315       Liberia  suspected         NaN 2014-09-02        2014-09-02  2014-09-08             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33316       Liberia  suspected         NaN 2014-10-23        2014-10-23  2014-10-25             NaT                      NaN   9.0            NaN               No         Not Hospitalised             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33317       Liberia  suspected         NaN 2014-09-02        2014-09-02  2014-09-02             NaT                      NaN  56.0    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33318       Liberia  confirmed         NaN        NaT        2015-01-03         NaN             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33319       Liberia  confirmed         NaN        NaT        2015-01-03  2014-09-29             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33320       Liberia  confirmed       Alive        NaT        2014-08-22         NaN             NaT                      NaN   NaN            NaN              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33321       Liberia   probable         NaN        NaT        2014-10-30         NaN             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33322       Liberia  confirmed         NaN        NaT        2015-01-03  2014-11-11             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33323       Liberia   probable         NaN 2014-11-03        2014-11-03  2014-11-09             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33324       Liberia  confirmed        Dead 2014-08-17        2014-08-17         NaN             NaT                      NaN   NaN    MONTSERRADO              Yes          Unknown TC Type             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33325       Liberia  confirmed         NaN        NaT        2014-10-01         NaN             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33326       Liberia  confirmed         NaN        NaT        2015-01-15  2014-09-16             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33327       Liberia  suspected        Dead 2014-08-09        2014-08-09         NaN             NaT                      NaN   5.0    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33328       Liberia  suspected         NaN        NaT        2014-10-02         NaN             NaT                      NaN   8.0    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33329       Liberia  confirmed         NaN        NaT        2015-01-03         NaN             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33330       Liberia  confirmed         NaN        NaT        2014-10-01         NaN             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33331       Liberia  confirmed         NaN 2014-08-11        2014-08-11  2014-08-16             NaT                      NaN  42.0          NIMBA              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33332       Liberia  suspected         NaN        NaT        2014-10-07         NaN             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33333       Liberia  suspected         NaN 2014-08-21        2014-08-21  2014-08-21             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33335       Liberia   probable         NaN 2014-10-17        2014-10-17  2014-10-23             NaT                      NaN   NaN    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Oct - Dec 2014          False      NaT
# 33336       Liberia  confirmed         NaN        NaT        2014-08-17         NaN             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33337       Liberia  confirmed         NaN        NaT        2014-08-28         NaN             NaT                      NaN  26.0    MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN       Jul - Sep 2014          False      NaT
# 33338       Liberia  confirmed         NaN        NaT        2015-01-03         NaN             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
# 33339       Liberia  confirmed         NaN        NaT        2015-01-15  2014-10-03             NaT                      NaN   NaN            NaN              NaN  Hospitalisation Unknown             NaN                          NaN       Jan - Mar 2015          False      NaT
#
# [33338 rows x 17 columns]

# %%
df['Duration_float'] = df['Duration'] / np.timedelta64(1, 'D')
df.loc[df.Duration_float < 0, 'Duration_float'] = np.nan
df[['Duration_float', 'FinalStatus']].groupby('FinalStatus').agg(['min', 'mean', 'median', 'std', 'max'])
# Out:
#             Duration_float
#                        min       mean median        std    max
# FinalStatus
# Alive                  0.0  22.698677   17.0  27.982544  278.0
# Dead                   0.0  10.950981    6.0  18.815632  363.0

# %% [markdown]
# ## Data Filtering

# %% [markdown]
# ### Rename columns

# %%
df_clean = df.rename(mapper={
    'Country': 'country', 
    'CL_DistrictRes': 'district', 
    'DateOnsetInferred': 'infection_date', 
    'DateOutcomeComp': 'recovery_date'
}, axis=1)

# %% [markdown]
# ### Exclude retrospective cases from the analysis.

# %% [markdown]
# Number of retrospective cases.

# %%
df_clean.retrospective.sum()
# Out:
# 4830

# %% [markdown]
# Count the number of non-retrospective cases per district.

# %%
df_clean['not_retrospective'] = ~df_clean['retrospective']
df_clean[['district', 'not_retrospective']].groupby('district').sum().sort_values('not_retrospective').head()
# Out:
#             not_retrospective
# district
# DINGUIRAYE                0.0
# TOUGUE                    2.0
# MALI                      3.0
# PITA                      6.0
# BONTHE                    6.0

# %% [markdown]
# So the `DINGUIRAYE` will be excluded from the dataset.

# %%
df_clean = df_clean[~df_clean.retrospective]
df_clean.shape
# Out:
# (28508, 19)

# %% [markdown]
# ### Exclude cases without a known district.

# %% [markdown]
# Numbe of cases without a known district to exclude.

# %%
df_clean.district.isna().sum()
# Out:
# 952

# %%
df_clean = df_clean[~df_clean.district.isna()]
df_clean.shape
# Out:
# (27556, 19)

# %% [markdown]
# ### Exclude cases with no infection date (i.e. `DateOnsetInferred`).

# %%
df_clean.infection_date.isna().sum()
# Out:
# 20

# %%
df_clean[df_clean.infection_date.isna()]
# Out:
#             country EpiCaseDef FinalStatus DateOnset infection_date DateReport recovery_date DateHospitalCurrentAdmit   Age     district HospitalizedEver      TreatmentCendreType TreatmentCentre  delay.onset.hospitalisation QuarterOnsetInferred  retrospective Duration  Duration_float  not_retrospective
# 5424   Sierra Leone  suspected         NaN       NaT            NaT        NaN           NaT                      NaN   0.0      WESTERN               No         Not Hospitalised             NaN                          NaN                  NaN          False      NaT             NaN               True
# 23937       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN   NaN         BONG               No         Not Hospitalised             NaN                          NaN                  NaN          False      NaT             NaN               True
# 23969       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN   NaN  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 24283       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN  61.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 24894       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN   9.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 25048       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN   NaN  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 25830       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN  38.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 25839       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN  36.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 26414       Liberia   probable         NaN       NaT            NaT        NaN           NaT                      NaN  28.0        NIMBA               No         Not Hospitalised             NaN                          NaN                  NaN          False      NaT             NaN               True
# 26676       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN  36.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 27078       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN  22.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 27470       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN  14.0  MONTSERRADO              Yes                      ETU  Montserrado 70                          NaN                  NaN          False      NaT             NaN               True
# 27761       Liberia   probable         NaN       NaT            NaT        NaN           NaT                      NaN  11.0        NIMBA               No         Not Hospitalised             NaN                          NaN                  NaN          False      NaT             NaN               True
# 28437       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN   NaN  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 29962       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN  27.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 30245       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN   NaN  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 30256       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN  95.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 30597       Liberia   probable         NaN       NaT            NaT        NaN           NaT                      NaN  20.0        NIMBA              Yes          Unknown TC Type             NaN                          NaN                  NaN          False      NaT             NaN               True
# 31149       Liberia  confirmed         NaN       NaT            NaT        NaN           NaT                      NaN  11.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True
# 31241       Liberia  suspected         NaN       NaT            NaT        NaN           NaT                      NaN  95.0  MONTSERRADO              NaN  Hospitalisation Unknown             NaN                          NaN                  NaN          False      NaT             NaN               True

# %%
df_clean = df_clean[~df_clean.infection_date.isna()]
df_clean.shape
# Out:
# (27536, 19)

# %% [markdown]
# ### Filter columns.

# %%
df_clean = df_clean[['district', 'infection_date', 'recovery_date']]
print(df_clean.shape)
df_clean.head()
# Out:
# (27536, 3)
#      district infection_date recovery_date
# 4  FORECARIAH     2015-03-15    2015-03-18
# 5   GUECKEDOU     2014-06-06    2014-06-16
# 6   GUECKEDOU     2014-02-27    2014-03-03
# 7        BOKE     2015-06-26    2015-07-15
# 8  N'ZEREKORE     2014-11-17    2014-11-24

# %% [markdown]
# ### Exclude cases with bogus dates
#
# Exclude bogus recovery dates (i.e. `DateOutcomeComp`) prior to infection dates (i.e. `DateOnsetInferred`)

# %%
print(df_clean[df_clean.recovery_date < df_clean.infection_date].shape)
df_clean[df_clean.recovery_date < df_clean.infection_date]
# Out:
# (5, 3)
#           district infection_date recovery_date
# 6485            BO     2014-12-24    2014-12-06
# 8583       WESTERN     2014-11-14    2014-09-13
# 9147       WESTERN     2014-10-29    2014-10-20
# 20351      WESTERN     2014-11-14    2014-09-15
# 25570  MONTSERRADO     2014-10-02    2014-09-28

# %%
df_clean = df_clean[~(df_clean.recovery_date < df_clean.infection_date)]
df_clean.shape
# Out:
# (27531, 3)

# %% [markdown]
# ### Normalize the district names

# %%
df_clean.district = df_clean.district.apply(lambda name: name.replace(' ', '_').replace("'", ""))

# %%
sorted(df_clean.district.unique())
# Out:
# ['BEYLA',
#  'BO',
#  'BOFFA',
#  'BOKE',
#  'BOMBALI',
#  'BOMI',
#  'BONG',
#  'BONTHE',
#  'CONAKRY',
#  'COYAH',
#  'DABOLA',
#  'DALABA',
#  'DUBREKA',
#  'FARANAH',
#  'FORECARIAH',
#  'FRIA',
#  'GBARPOLU',
#  'GRAND_BASSA',
#  'GRAND_CAPE_MOUNT',
#  'GRAND_GEDEH',
#  'GRAND_KRU',
#  'GUECKEDOU',
#  'KAILAHUN',
#  'KAMBIA',
#  'KANKAN',
#  'KENEMA',
#  'KEROUANE',
#  'KINDIA',
#  'KISSIDOUGO',
#  'KOINADUGU',
#  'KONO',
#  'KOUROUSSA',
#  'LOFA',
#  'LOLA',
#  'MACENTA',
#  'MALI',
#  'MARGIBI',
#  'MARYLAND',
#  'MONTSERRADO',
#  'MOYAMBA',
#  'NIMBA',
#  'NZEREKORE',
#  'PITA',
#  'PORT_LOKO',
#  'PUJEHUN',
#  'RIVERCESS',
#  'RIVER_GEE',
#  'SIGUIRI',
#  'SINOE',
#  'TELIMELE',
#  'TONKOLILI',
#  'TOUGUE',
#  'WESTERN',
#  'YOMOU']

# %% [markdown]
# Check the that the number of districts in the cleaned dataset is equal to 54 (55 districs excluding DINGUIRAYE due to retrospective cases).

# %%
len(df_clean.district.unique())
# Out:
# 54

# %% [markdown]
# Visualize the dataset.

# %%
print(df_clean.shape)
df_clean.head()
# Out:
# (27531, 3)
#      district infection_date recovery_date
# 4  FORECARIAH     2015-03-15    2015-03-18
# 5   GUECKEDOU     2014-06-06    2014-06-16
# 6   GUECKEDOU     2014-02-27    2014-03-03
# 7        BOKE     2015-06-26    2015-07-15
# 8   NZEREKORE     2014-11-17    2014-11-24

# %% [markdown]
# Save the cleaned dataset.

# %%
df_clean.to_csv(os.path.join(DATA_DIR, 'ebola', 'rstb20160308_si_001_filtered.csv'), index=False)

# %% [markdown]
# Delete the raw dataframe before continuing processing.

# %%
del df

# %% [markdown]
# ---

# %% [markdown]
# ## Process the data into time series for the analysis

# %% [markdown]
# Load the clean dataset

# %%
df_clean = pd.read_csv(os.path.join(DATA_DIR, 'ebola', 'rstb20160308_si_001_filtered.csv'),
                       parse_dates=['infection_date', 'recovery_date'], 
                       infer_datetime_format=True)
print(df_clean.shape)
df_clean.head()
# Out:
# (27531, 3)
#      district infection_date recovery_date
# 0  FORECARIAH     2015-03-15    2015-03-18
# 1   GUECKEDOU     2014-06-06    2014-06-16
# 2   GUECKEDOU     2014-02-27    2014-03-03
# 3        BOKE     2015-06-26    2015-07-15
# 4   NZEREKORE     2014-11-17    2014-11-24

# %% [markdown]
# Number of cases with no recovery date

# %%
df_clean.recovery_date.isna().sum()
# Out:
# 20196

# %% [markdown]
# Format the dates into timestamps in days (the extracted timestamps are initially in ns).

# %%
df_clean['infection_timestamp'] = df_clean.infection_date.values.astype(np.int64) / (10 ** 9 * 60 * 60 * 24)
df_clean['recovery_timestamp'] = df_clean.recovery_date.values.astype(np.int64) / (10 ** 9 * 60 * 60 * 24)
df_clean.loc[df_clean.recovery_date.isna(),'recovery_timestamp'] = np.nan

# %% [markdown]
# ### Explore the infection duration

# %% [markdown]
# Compute the duration of infection period

# %%
df_clean['infection_duration'] = df_clean['recovery_timestamp'] - df_clean['infection_timestamp']

# %% [markdown]
# Visualize it

# %%
df_clean.sort_values('infection_duration', ascending=False)
# Out:
#           district infection_date recovery_date  infection_timestamp  recovery_timestamp  infection_duration
# 15746    KOINADUGU     2014-05-17    2015-05-15              16207.0             16570.0               363.0
# 7937       WESTERN     2014-10-29    2015-08-03              16372.0             16650.0               278.0
# 7950          KONO     2014-10-29    2015-07-30              16372.0             16646.0               274.0
# 1766       CONAKRY     2014-03-24    2014-12-10              16153.0             16414.0               261.0
# 21484         BOMI     2014-03-03    2014-11-10              16132.0             16384.0               252.0
# 11579    PORT_LOKO     2014-10-01    2015-05-06              16344.0             16561.0               217.0
# 14307         KONO     2014-09-19    2015-04-23              16332.0             16548.0               216.0
# 7416     PORT_LOKO     2014-10-05    2015-05-06              16348.0             16561.0               213.0
# 2900     GUECKEDOU     2014-05-19    2014-12-17              16209.0             16421.0               212.0
# 4001     PORT_LOKO     2014-09-04    2015-04-02              16317.0             16527.0               210.0
# 26718      WESTERN     2014-10-05    2015-05-01              16348.0             16556.0               208.0
# 10967    PORT_LOKO     2014-09-16    2015-04-07              16329.0             16532.0               203.0
# 1364         BOFFA     2014-05-02    2014-11-20              16192.0             16394.0               202.0
# 17848    PORT_LOKO     2014-09-18    2015-04-07              16331.0             16532.0               201.0
# 3577     PORT_LOKO     2014-10-04    2015-04-22              16347.0             16547.0               200.0
# 18307    PORT_LOKO     2014-09-15    2015-04-01              16328.0             16526.0               198.0
# 10174    PORT_LOKO     2014-09-22    2015-04-07              16335.0             16532.0               197.0
# 12063    PORT_LOKO     2014-10-25    2015-05-06              16368.0             16561.0               193.0
# 10545    PORT_LOKO     2014-10-25    2015-05-04              16368.0             16559.0               191.0
# 15002    PORT_LOKO     2014-10-27    2015-05-04              16370.0             16559.0               189.0
# 3782     PORT_LOKO     2014-10-16    2015-04-22              16359.0             16547.0               188.0
# 27056    PORT_LOKO     2014-10-30    2015-05-06              16373.0             16561.0               188.0
# 9634     PORT_LOKO     2014-10-28    2015-05-04              16371.0             16559.0               188.0
# 19502    PORT_LOKO     2014-10-02    2015-04-07              16345.0             16532.0               187.0
# 26409    PORT_LOKO     2014-09-28    2015-04-03              16341.0             16528.0               187.0
# 15753    PORT_LOKO     2014-09-26    2015-04-01              16339.0             16526.0               187.0
# 26659    PORT_LOKO     2014-11-01    2015-05-06              16375.0             16561.0               186.0
# 16674    PORT_LOKO     2014-10-30    2015-05-04              16373.0             16559.0               186.0
# 7487     PORT_LOKO     2014-10-30    2015-05-04              16373.0             16559.0               186.0
# 11532    PORT_LOKO     2014-10-19    2015-04-23              16362.0             16548.0               186.0
# ...            ...            ...           ...                  ...                 ...                 ...
# 27501      WESTERN     2014-12-16           NaT              16420.0                 NaN                 NaN
# 27502      WESTERN     2014-11-11           NaT              16385.0                 NaN                 NaN
# 27503      WESTERN     2014-10-29           NaT              16372.0                 NaN                 NaN
# 27504      WESTERN     2015-04-16           NaT              16541.0                 NaN                 NaN
# 27505           BO     2014-12-13           NaT              16417.0                 NaN                 NaN
# 27506      WESTERN     2014-12-19           NaT              16423.0                 NaN                 NaN
# 27507      BOMBALI     2014-11-01           NaT              16375.0                 NaN                 NaN
# 27508      WESTERN     2015-03-03           NaT              16497.0                 NaN                 NaN
# 27509    KOINADUGU     2015-05-11           NaT              16566.0                 NaN                 NaN
# 27510         KONO     2015-01-13           NaT              16448.0                 NaN                 NaN
# 27511      WESTERN     2014-12-20           NaT              16424.0                 NaN                 NaN
# 27512           BO     2015-06-15           NaT              16601.0                 NaN                 NaN
# 27513      WESTERN     2014-12-03           NaT              16407.0                 NaN                 NaN
# 27514         KONO     2015-01-10           NaT              16445.0                 NaN                 NaN
# 27515         KONO     2015-01-13           NaT              16448.0                 NaN                 NaN
# 27516  MONTSERRADO     2014-08-27           NaT              16309.0                 NaN                 NaN
# 27517  MONTSERRADO     2014-09-01           NaT              16314.0                 NaN                 NaN
# 27518  MONTSERRADO     2014-09-02           NaT              16315.0                 NaN                 NaN
# 27519  MONTSERRADO     2014-09-02           NaT              16315.0                 NaN                 NaN
# 27520  MONTSERRADO     2014-10-30           NaT              16373.0                 NaN                 NaN
# 27521  MONTSERRADO     2014-11-03           NaT              16377.0                 NaN                 NaN
# 27522  MONTSERRADO     2014-08-17           NaT              16299.0                 NaN                 NaN
# 27523  MONTSERRADO     2014-10-01           NaT              16344.0                 NaN                 NaN
# 27524  MONTSERRADO     2014-08-09           NaT              16291.0                 NaN                 NaN
# 27525  MONTSERRADO     2014-10-02           NaT              16345.0                 NaN                 NaN
# 27526  MONTSERRADO     2014-10-01           NaT              16344.0                 NaN                 NaN
# 27527        NIMBA     2014-08-11           NaT              16293.0                 NaN                 NaN
# 27528  MONTSERRADO     2014-08-21           NaT              16303.0                 NaN                 NaN
# 27529  MONTSERRADO     2014-10-17           NaT              16360.0                 NaN                 NaN
# 27530  MONTSERRADO     2014-08-28           NaT              16310.0                 NaN                 NaN
#
# [27531 rows x 6 columns]

# %% [markdown]
# Show some statistics.

# %%
valid_duration_mask = ~df_clean.infection_duration.isna()

# %%
df_clean.infection_duration[valid_duration_mask].describe()
# Out:
# count    7335.000000
# mean       18.977641
# std        25.735762
# min         0.000000
# 25%         7.000000
# 50%        12.000000
# 75%        20.000000
# max       363.000000
# Name: infection_duration, dtype: float64

# %% [markdown]
# And the median duration.

# %%
df_clean.infection_duration[~df_clean.infection_duration.isna()].median()
# Out:
# 12.0

# %%
plt.hist(df_clean.infection_duration[~df_clean.infection_duration.isna()], 
         bins=363, density=False, histtype='step', cumulative=-1, label='Reversed emp.');
plt.yscale('log');

# %% [markdown]
# Since a large proportion of recovery dates are missing, and since some dates seems unreasonably long, we will ignore all recovery dates in our analysis.

# %%
df_clean = df_clean.drop(['recovery_date', 'recovery_timestamp', 'infection_duration'], axis=1)

# %% [markdown]
# ---

# %% [markdown]
# Sort by timestamp.

# %%
df_clean = df_clean.sort_values('infection_timestamp')

# %% [markdown]
# Remove the minimum timestamp.

# %%
min_timestamp = df_clean.infection_timestamp.min()
df_clean.infection_timestamp -= min_timestamp

# %%
df_clean.reset_index()
# Out:
#        index    district infection_date  infection_timestamp
# 0       5764     WESTERN     2013-12-26                  0.0
# 1      13244     PUJEHUN     2013-12-26                  0.0
# 2      18816   TONKOLILI     2014-01-01                  6.0
# 3      11730     WESTERN     2014-01-01                  6.0
# 4       2299   GUECKEDOU     2014-01-01                  6.0
# 5       1200   GUECKEDOU     2014-01-01                  6.0
# 6       1452   GUECKEDOU     2014-01-06                 11.0
# 7       1267   GUECKEDOU     2014-01-15                 20.0
# 8        372   GUECKEDOU     2014-01-20                 25.0
# 9       1040   GUECKEDOU     2014-01-25                 30.0
# 10     18146     WESTERN     2014-01-26                 31.0
# 11      1520   GUECKEDOU     2014-01-29                 34.0
# 12       137   GUECKEDOU     2014-02-01                 37.0
# 13       479   GUECKEDOU     2014-02-02                 38.0
# 14      2102   GUECKEDOU     2014-02-03                 39.0
# 15      2542   GUECKEDOU     2014-02-03                 39.0
# 16      1885   GUECKEDOU     2014-02-04                 40.0
# 17      1603   GUECKEDOU     2014-02-04                 40.0
# 18       656   GUECKEDOU     2014-02-11                 47.0
# 19      8522     WESTERN     2014-02-15                 51.0
# 20       793   GUECKEDOU     2014-02-16                 52.0
# 21       408     MACENTA     2014-02-17                 53.0
# 22      1052   GUECKEDOU     2014-02-18                 54.0
# 23       114     MACENTA     2014-02-19                 55.0
# 24      2855   GUECKEDOU     2014-02-21                 57.0
# 25      2110   GUECKEDOU     2014-02-23                 59.0
# 26     22915        BONG     2014-02-24                 60.0
# 27      1784   GUECKEDOU     2014-02-25                 61.0
# 28      1049     MACENTA     2014-02-25                 61.0
# 29         2   GUECKEDOU     2014-02-27                 63.0
# ...      ...         ...            ...                  ...
# 27501  13818     WESTERN     2015-08-20                602.0
# 27502   8555          BO     2015-08-20                602.0
# 27503   5985     WESTERN     2015-08-20                602.0
# 27504   6148     WESTERN     2015-08-20                602.0
# 27505  13943          BO     2015-08-20                602.0
# 27506  15104      KAMBIA     2015-08-20                602.0
# 27507  10642        KONO     2015-08-21                603.0
# 27508   6015        KONO     2015-08-21                603.0
# 27509  15461      KAMBIA     2015-08-21                603.0
# 27510    332     CONAKRY     2015-08-21                603.0
# 27511   7197     WESTERN     2015-08-21                603.0
# 27512   5430          BO     2015-08-21                603.0
# 27513   4952          BO     2015-08-21                603.0
# 27514  18339        KONO     2015-08-23                605.0
# 27515  26453      KAMBIA     2015-08-23                605.0
# 27516   1146     CONAKRY     2015-08-27                609.0
# 27517    429     CONAKRY     2015-08-31                613.0
# 27518   1399     CONAKRY     2015-09-19                632.0
# 27519   1185     CONAKRY     2015-09-22                635.0
# 27520   2552     CONAKRY     2015-09-23                636.0
# 27521    798     CONAKRY     2015-09-23                636.0
# 27522    567     CONAKRY     2015-09-23                636.0
# 27523    708     CONAKRY     2015-09-24                637.0
# 27524   1247     CONAKRY     2015-09-24                637.0
# 27525   2707  FORECARIAH     2015-09-25                638.0
# 27526   2428  FORECARIAH     2015-09-25                638.0
# 27527   2344     CONAKRY     2015-09-25                638.0
# 27528   2131     CONAKRY     2015-09-25                638.0
# 27529   2061     CONAKRY     2015-09-25                638.0
# 27530   1326     DUBREKA     2015-09-25                638.0
#
# [27531 rows x 4 columns]

# %%
df_clean.infection_date.min(), df_clean.infection_date.max()
# Out:
# (Timestamp('2013-12-26 00:00:00'), Timestamp('2015-09-25 00:00:00'))

# %% [markdown]
# Save resulting dataframe.

# %%
df_clean.to_csv(os.path.join(DATA_DIR, 'ebola', 'rstb20160308_si_001_cleaned.csv'), index=False)

# %% [markdown]
# ## Format clean dataframe into time series

# %%
df_ts = pd.DataFrame(df_clean.groupby('district').infection_timestamp.apply(list))

# %%
print(df_ts.shape)
display(df_ts.head())
# Out:
# (54, 1)
#                                         infection_timestamp
# district
# BEYLA     [233.0, 260.0, 266.0, 273.0, 279.0, 284.0, 284...
# BO        [176.0, 188.0, 190.0, 190.0, 191.0, 193.0, 194...
# BOFFA     [127.0, 143.0, 144.0, 144.0, 145.0, 146.0, 147...
# BOKE      [277.0, 496.0, 497.0, 497.0, 498.0, 513.0, 524...
# BOMBALI   [162.0, 183.0, 194.0, 203.0, 205.0, 205.0, 207...

# %%
df_ts.to_csv(os.path.join(DATA_DIR, 'ebola', 'rstb20160308_si_001_time_series.csv'), index=True)
